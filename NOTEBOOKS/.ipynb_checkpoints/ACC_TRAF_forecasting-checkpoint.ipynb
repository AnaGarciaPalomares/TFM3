# %% [markdown]
# # ACCIDENTES DE TRÁFICO - FORECASTING

# %% [markdown]
# Importamos los paquetes que vamos a necesitar:

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from statsmodels.tools.eval_measures import rmse
from sklearn.metrics import r2_score

# %%
# %%capture
pip install pmdarima

# %%
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
# %%capture
pip install fbprophet

# %%
import fbprophet
print('Prophet %s' % fbprophet.__version__)
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot, plot_cross_validation_metric
from prophet.diagnostics import cross_validation, performance_metrics
# Out:
# Prophet 0.7.1

# %%
# %%capture
# !pip install tensorflow

# %%
from keras.models import Sequential
from keras.models import Model

from keras.layers import Dense,Activation,Flatten
from keras.layers import Input, Embedding, Dense, Flatten, Dropout, concatenate, LSTM
from keras.layers import BatchNormalization, SpatialDropout1D

from sklearn.preprocessing import MinMaxScaler

from keras.callbacks import Callback

from keras.optimizers import Adam
# Out:
# 2022-06-17 11:36:57.732915: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-17 11:36:57.732948: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path_acc = '/home/dsc/Master DS/TFM/GIT/DATOS_PROCESADOS/accidentes.csv'
accidents = pd.read_csv(path_acc, sep = '^' )

# %% [markdown]
# Generamos un dataframe de recuentos de accidentes, donde el índice sea la fecha del recuento con formato 'datetime'.

# %%
ser_temp_df = accidents [['fecha','fecha_datetime','ano_fecha','dia_sem','dia_sem_code','mes','es_finde','es_fest']]

# %%
num_siniestros = accidents.groupby('fecha_datetime').count().reset_index()

# %%
num_siniestros = num_siniestros.rename(columns={'fecha':'num_claims'})

# %%
num_siniestros_df = num_siniestros[['fecha_datetime','num_claims']]

# %%
ser_temp_df.drop_duplicates(inplace=True)

# %%
accidents = num_siniestros_df.merge (ser_temp_df)

# %%
var_drop=['fecha']

# %%
accidents.drop(var_drop, inplace=True, axis=1)

# %%
num_sin_año = accidents [['fecha_datetime', 'num_claims']]

# %%
num_sin_año['datetime'] = pd.to_datetime(num_sin_año['fecha_datetime'], format='%Y-%m-%d')

# %%
num_sin_año.drop('fecha_datetime', inplace=True, axis=1)

# %%
num_sin_año.set_index('datetime', inplace = True)

# %% [markdown]
# Todo los modelos predictivos que vamos a probar van a considerar todo el periodo de muestra como train a excepcion del ultimo mes de diciembre 2021, que serán nuestros datos de test.

# %%
train_graf = num_sin_año.loc['2019-01-01': '2021-11-30']
test_graf = num_sin_año.loc['2021-12-01': '2021-12-31']

# %%
fig,ax = plt.subplots(1,1,figsize=(18,4))
plt.plot(train_graf, color = "black")
plt.plot(test_graf, color = "red")
plt.ylabel('Nº siniestros')
plt.xlabel('Fecha')
plt.xticks(rotation=45)
plt.title("Train/Test para nº siniestros")
plt.show()

# %% [markdown]
# Los modelos que vamos a aplicar son los siguientes:
#
# - Modelo estadístico tradicional con componente estacional -- SARIMA
# - Modelo estadístico Bayesiano -- PROPHET
# - Deep learning -- Red neuronal

# %% [markdown]
# ## A. SARIMA

# %% [markdown]
# Un modelo SARIMA tiene los siguientes componentes:
#
# - **AR(p) Autoregresión**
#     - Un modelo de regresión que utiliza la relación dependiente entre una observación actual y las observaciones durante un período anterior
#     - El número de rezagos de Y que se utilizarán como predictores
#
# - **I(d) Integración**
#     - Utiliza la diferenciación de observaciones para hacer estacionaria la serie de tiempo
#     - La diferenciación implica la resta de los valores actuales de una serie con sus valores anteriores "d" número de veces
#
# - **MA(q) Media móvil**
#     - Un componente de media móvil representa el error del modelo como una combinación de términos de error anteriores
#     - El número de errores de pronóstico retrasados que deben incluirse en el modelo ARIMA
#
# Predicción Yt = Constante + Combinación lineal Retrasos de Y (hasta q rezagos) + Combinación lineal de errores de pronóstico rezagados (hasta q rezagos)
#
# - **S(m) Estacional**: Si la serie temporal tiene una estacionalidad definida, que utiliza la diferenciación estacional. La diferenciación estacional es similar a la diferenciación regular, pero, en lugar de restar términos consecutivos, resta el valor de la temporada anterior.

# %% [markdown]
# Como no estamos seguros de los parametros de nuestro modelo vamos a aplicar un grid de busqueda, donde:
# - AR, MA: busqueda en los rangos (0 ,3)
# - d = 1, sabemos que hay que eliminar la tendencia para hacer la serie estacionaria
# - s = 7, sabemos que hay estacionalidad semanal

# %%
# Rango de parametros
p = range(0,3)
q = range(0,3)
d = range(1,2) # Eliminación de la tendencia con la resta de los valores anteriores
s = 7 # Estacionalidad semanal

# Lista de todas la combinaciones de parametros
pdq = list(itertools.product(p, d, q))
# Aplicamos lo mismo para el componente estacional
seasonal_pdq = [(x[0], x[1], x[2], 7) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_graf,
                                            order=param,
                                            seasonal_order=param_seasonal)
            results = mod.fit(max_iter = 50, method = 'powell')

            print('SARIMA{},{}7 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 4.197063
#          Iterations: 1
#          Function evaluations: 11
# SARIMA(0, 1, 0),(0, 1, 0, 7)7 - AIC:8941.743773641387
# Optimization terminated successfully.
#          Current function value: 3.909068
#          Iterations: 2
#          Function evaluations: 48
# SARIMA(0, 1, 0),(0, 1, 1, 7)7 - AIC:8330.314114858384
# Optimization terminated successfully.
#          Current function value: 3.907456
#          Iterations: 2
#          Function evaluations: 70
# SARIMA(0, 1, 0),(0, 1, 2, 7)7 - AIC:8328.88120989775
# Optimization terminated successfully.
#          Current function value: 4.082975
#          Iterations: 1
#          Function evaluations: 23
# SARIMA(0, 1, 0),(1, 1, 0, 7)7 - AIC:8700.73673029459
# Optimization terminated successfully.
#          Current function value: 3.907746
#          Iterations: 4
#          Function evaluations: 153
# SARIMA(0, 1, 0),(1, 1, 1, 7)7 - AIC:8329.499602119153
# Optimization terminated successfully.
#          Current function value: 3.906648
#          Iterations: 3
#          Function evaluations: 150
# SARIMA(0, 1, 0),(1, 1, 2, 7)7 - AIC:8329.15992898951
# Optimization terminated successfully.
#          Current function value: 4.006819
#          Iterations: 1
#          Function evaluations: 35
# SARIMA(0, 1, 0),(2, 1, 0, 7)7 - AIC:8540.524681054085
# Optimization terminated successfully.
#          Current function value: 3.907414
#          Iterations: 6
#          Function evaluations: 301
# SARIMA(0, 1, 0),(2, 1, 1, 7)7 - AIC:8330.791698226598
# Optimization terminated successfully.
#          Current function value: 3.906607
#          Iterations: 3
#          Function evaluations: 180
# SARIMA(0, 1, 0),(2, 1, 2, 7)7 - AIC:8331.07388228586
# Optimization terminated successfully.
#          Current function value: 4.040335
#          Iterations: 2
#          Function evaluations: 58
# SARIMA(0, 1, 1),(0, 1, 0, 7)7 - AIC:8609.91357175848
# Optimization terminated successfully.
#          Current function value: 3.750738
#          Iterations: 3
#          Function evaluations: 116
# SARIMA(0, 1, 1),(0, 1, 1, 7)7 - AIC:7995.0712312365695
# Optimization terminated successfully.
#          Current function value: 3.749502
#          Iterations: 2
#          Function evaluations: 91
# SARIMA(0, 1, 1),(0, 1, 2, 7)7 - AIC:7994.440084726984
# Optimization terminated successfully.
#          Current function value: 3.916618
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(0, 1, 1),(1, 1, 0, 7)7 - AIC:8348.396141104648
# Optimization terminated successfully.
#          Current function value: 3.749507
#          Iterations: 3
#          Function evaluations: 145
# SARIMA(0, 1, 1),(1, 1, 1, 7)7 - AIC:7994.449291269784
# Optimization terminated successfully.
#          Current function value: 3.749334
#          Iterations: 3
#          Function evaluations: 184
# SARIMA(0, 1, 1),(1, 1, 2, 7)7 - AIC:7996.081214384769
# Optimization terminated successfully.
#          Current function value: 3.845929
#          Iterations: 2
#          Function evaluations: 98
# SARIMA(0, 1, 1),(2, 1, 0, 7)7 - AIC:8199.829278565812
# Optimization terminated successfully.
#          Current function value: 3.749542
#          Iterations: 6
#          Function evaluations: 371
# SARIMA(0, 1, 1),(2, 1, 1, 7)7 - AIC:7996.525495445705
# Optimization terminated successfully.
#          Current function value: 3.749557
#          Iterations: 3
#          Function evaluations: 219
# SARIMA(0, 1, 1),(2, 1, 2, 7)7 - AIC:7998.555860316714
# Optimization terminated successfully.
#          Current function value: 4.008142
#          Iterations: 3
#          Function evaluations: 126
# SARIMA(0, 1, 2),(0, 1, 0, 7)7 - AIC:8543.343231314011
# Optimization terminated successfully.
#          Current function value: 3.744448
#          Iterations: 3
#          Function evaluations: 147
# SARIMA(0, 1, 2),(0, 1, 1, 7)7 - AIC:7983.675260466899
# Optimization terminated successfully.
#          Current function value: 3.742784
#          Iterations: 2
#          Function evaluations: 111
# SARIMA(0, 1, 2),(0, 1, 2, 7)7 - AIC:7982.13034945907
# Optimization terminated successfully.
#          Current function value: 3.910466
#          Iterations: 2
#          Function evaluations: 94
# SARIMA(0, 1, 2),(1, 1, 0, 7)7 - AIC:8337.29262765237
# Optimization terminated successfully.
#          Current function value: 3.742804
#          Iterations: 4
#          Function evaluations: 233
# SARIMA(0, 1, 2),(1, 1, 1, 7)7 - AIC:7982.1724082672345
# Optimization terminated successfully.
#          Current function value: 3.742474
#          Iterations: 3
#          Function evaluations: 219
# SARIMA(0, 1, 2),(1, 1, 2, 7)7 - AIC:7983.470260055652
# Optimization terminated successfully.
#          Current function value: 3.839414
#          Iterations: 2
#          Function evaluations: 119
# SARIMA(0, 1, 2),(2, 1, 0, 7)7 - AIC:8187.951178900148
# Optimization terminated successfully.
#          Current function value: 3.742819
#          Iterations: 7
#          Function evaluations: 507
# SARIMA(0, 1, 2),(2, 1, 1, 7)7 - AIC:7984.203663142285
# Optimization terminated successfully.
#          Current function value: 3.742566
#          Iterations: 4
#          Function evaluations: 326
# SARIMA(0, 1, 2),(2, 1, 2, 7)7 - AIC:7985.665432913928
# Optimization terminated successfully.
#          Current function value: 4.106877
#          Iterations: 1
#          Function evaluations: 25
# SARIMA(1, 1, 0),(0, 1, 0, 7)7 - AIC:8751.648738417633
# Optimization terminated successfully.
#          Current function value: 3.820268
#          Iterations: 2
#          Function evaluations: 74
# SARIMA(1, 1, 0),(0, 1, 1, 7)7 - AIC:8143.170298281303
# Optimization terminated successfully.
#          Current function value: 3.818820
#          Iterations: 2
#          Function evaluations: 91
# SARIMA(1, 1, 0),(0, 1, 2, 7)7 - AIC:8142.086558096187
# Optimization terminated successfully.
#          Current function value: 3.989645
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(1, 1, 0),(1, 1, 0, 7)7 - AIC:8503.943279036605
# Optimization terminated successfully.
#          Current function value: 3.818886
#          Iterations: 3
#          Function evaluations: 147
# SARIMA(1, 1, 0),(1, 1, 1, 7)7 - AIC:8142.226338805896
# Optimization terminated successfully.
#          Current function value: 3.818660
#          Iterations: 3
#          Function evaluations: 190
# SARIMA(1, 1, 0),(1, 1, 2, 7)7 - AIC:8143.746643073128
# Optimization terminated successfully.
#          Current function value: 3.919298
#          Iterations: 2
#          Function evaluations: 97
# SARIMA(1, 1, 0),(2, 1, 0, 7)7 - AIC:8356.104815713416
# Optimization terminated successfully.
#          Current function value: 3.818753
#          Iterations: 5
#          Function evaluations: 316
# SARIMA(1, 1, 0),(2, 1, 1, 7)7 - AIC:8143.943114129726
# Optimization terminated successfully.
#          Current function value: 3.818621
#          Iterations: 4
#          Function evaluations: 296
# SARIMA(1, 1, 0),(2, 1, 2, 7)7 - AIC:8145.663381809064
# Optimization terminated successfully.
#          Current function value: 3.996801
#          Iterations: 3
#          Function evaluations: 144
# SARIMA(1, 1, 1),(0, 1, 0, 7)7 - AIC:8519.185687989559
# Optimization terminated successfully.
#          Current function value: 3.744055
#          Iterations: 3
#          Function evaluations: 139
# SARIMA(1, 1, 1),(0, 1, 1, 7)7 - AIC:7982.838103664946
# Optimization terminated successfully.
#          Current function value: 3.742127
#          Iterations: 3
#          Function evaluations: 177
# SARIMA(1, 1, 1),(0, 1, 2, 7)7 - AIC:7980.729885903252
# Optimization terminated successfully.
#          Current function value: 3.907842
#          Iterations: 4
#          Function evaluations: 196
# SARIMA(1, 1, 1),(1, 1, 0, 7)7 - AIC:8331.703046502571
# Optimization terminated successfully.
#          Current function value: 3.742262
#          Iterations: 4
#          Function evaluations: 233
# SARIMA(1, 1, 1),(1, 1, 1, 7)7 - AIC:7981.01837370499
# Optimization terminated successfully.
#          Current function value: 3.741827
#          Iterations: 4
#          Function evaluations: 289
# SARIMA(1, 1, 1),(1, 1, 2, 7)7 - AIC:7982.092308551899
# Optimization terminated successfully.
#          Current function value: 3.838882
#          Iterations: 3
#          Function evaluations: 185
# SARIMA(1, 1, 1),(2, 1, 0, 7)7 - AIC:8186.817925548356
# Optimization terminated successfully.
#          Current function value: 3.742143
#          Iterations: 7
#          Function evaluations: 515
# SARIMA(1, 1, 1),(2, 1, 1, 7)7 - AIC:7982.764719334306
# Optimization terminated successfully.
#          Current function value: 3.741906
#          Iterations: 4
#          Function evaluations: 329
# SARIMA(1, 1, 1),(2, 1, 2, 7)7 - AIC:7984.259757859242
# Optimization terminated successfully.
#          Current function value: 3.988772
#          Iterations: 2
#          Function evaluations: 169
# SARIMA(1, 1, 2),(0, 1, 0, 7)7 - AIC:8504.084339088371
# Optimization terminated successfully.
#          Current function value: 3.747997
#          Iterations: 3
#          Function evaluations: 172
# SARIMA(1, 1, 2),(0, 1, 1, 7)7 - AIC:7993.234607313536
# Optimization terminated successfully.
#          Current function value: 3.745139
#          Iterations: 3
#          Function evaluations: 205
# SARIMA(1, 1, 2),(0, 1, 2, 7)7 - AIC:7989.146467209922
# Optimization terminated successfully.
#          Current function value: 3.885579
#          Iterations: 2
#          Function evaluations: 137
# SARIMA(1, 1, 2),(1, 1, 0, 7)7 - AIC:8286.283329038119
# Optimization terminated successfully.
#          Current function value: 3.745771
#          Iterations: 5
#          Function evaluations: 372
# SARIMA(1, 1, 2),(1, 1, 1, 7)7 - AIC:7990.491638973502
# Optimization terminated successfully.
#          Current function value: 3.745558
#          Iterations: 3
#          Function evaluations: 248
# SARIMA(1, 1, 2),(1, 1, 2, 7)7 - AIC:7992.037776634174
# Optimization terminated successfully.
#          Current function value: 3.824649
#          Iterations: 4
#          Function evaluations: 351
# SARIMA(1, 1, 2),(2, 1, 0, 7)7 - AIC:8158.503333832612
# Optimization terminated successfully.
#          Current function value: 3.745662
#          Iterations: 6
#          Function evaluations: 550
# SARIMA(1, 1, 2),(2, 1, 1, 7)7 - AIC:7992.260289990137
# Optimization terminated successfully.
#          Current function value: 3.745176
#          Iterations: 5
#          Function evaluations: 477
# SARIMA(1, 1, 2),(2, 1, 2, 7)7 - AIC:7993.225903989375
# Optimization terminated successfully.
#          Current function value: 4.065422
#          Iterations: 1
#          Function evaluations: 37
# SARIMA(2, 1, 0),(0, 1, 0, 7)7 - AIC:8665.347916054414
# Optimization terminated successfully.
#          Current function value: 3.786952
#          Iterations: 3
#          Function evaluations: 146
# SARIMA(2, 1, 0),(0, 1, 1, 7)7 - AIC:8074.206955722829
# Optimization terminated successfully.
#          Current function value: 3.784958
#          Iterations: 2
#          Function evaluations: 117
# SARIMA(2, 1, 0),(0, 1, 2, 7)7 - AIC:8071.959883801337
# Optimization terminated successfully.
#          Current function value: 3.943633
#          Iterations: 2
#          Function evaluations: 97
# SARIMA(2, 1, 0),(1, 1, 0, 7)7 - AIC:8407.939278136442
# Optimization terminated successfully.
#          Current function value: 3.784921
#          Iterations: 4
#          Function evaluations: 243
# SARIMA(2, 1, 0),(1, 1, 1, 7)7 - AIC:8071.881467561805
# Optimization terminated successfully.
#          Current function value: 3.785226
#          Iterations: 3
#          Function evaluations: 227
# SARIMA(2, 1, 0),(1, 1, 2, 7)7 - AIC:8074.531565954307
# Optimization terminated successfully.
#          Current function value: 3.876907
#          Iterations: 2
#          Function evaluations: 122
# SARIMA(2, 1, 0),(2, 1, 0, 7)7 - AIC:8267.811173678652
# Optimization terminated successfully.
#          Current function value: 3.785168
#          Iterations: 6
#          Function evaluations: 445
# SARIMA(2, 1, 0),(2, 1, 1, 7)7 - AIC:8074.407536950415
# Optimization terminated successfully.
#          Current function value: 3.784885
#          Iterations: 4
#          Function evaluations: 341
# SARIMA(2, 1, 0),(2, 1, 2, 7)7 - AIC:8075.805656732091
# Optimization terminated successfully.
#          Current function value: 3.991211
#          Iterations: 4
#          Function evaluations: 210
# SARIMA(2, 1, 1),(0, 1, 0, 7)7 - AIC:8509.278691552368
# Optimization terminated successfully.
#          Current function value: 3.743910
#          Iterations: 4
#          Function evaluations: 236
# SARIMA(2, 1, 1),(0, 1, 1, 7)7 - AIC:7984.529272400899
# Optimization terminated successfully.
#          Current function value: 3.741804
#          Iterations: 4
#          Function evaluations: 278
# SARIMA(2, 1, 1),(0, 1, 2, 7)7 - AIC:7982.043349538299
# Optimization terminated successfully.
#          Current function value: 3.894203
#          Iterations: 8
#          Function evaluations: 495
# SARIMA(2, 1, 1),(1, 1, 0, 7)7 - AIC:8304.65282439382
# Optimization terminated successfully.
#          Current function value: 3.741821
#          Iterations: 5
#          Function evaluations: 348
# SARIMA(2, 1, 1),(1, 1, 1, 7)7 - AIC:7982.0777478319915
# Optimization terminated successfully.
#          Current function value: 3.741591
#          Iterations: 4
#          Function evaluations: 329
# SARIMA(2, 1, 1),(1, 1, 2, 7)7 - AIC:7983.589655107267
# Optimization terminated successfully.
#          Current function value: 3.838509
#          Iterations: 3
#          Function evaluations: 221
# SARIMA(2, 1, 1),(2, 1, 0, 7)7 - AIC:8188.024870680328
# Optimization terminated successfully.
#          Current function value: 3.743996
#          Iterations: 5
#          Function evaluations: 420
# SARIMA(2, 1, 1),(2, 1, 1, 7)7 - AIC:7988.710459017449
# Optimization terminated successfully.
#          Current function value: 3.741513
#          Iterations: 5
#          Function evaluations: 470
# SARIMA(2, 1, 1),(2, 1, 2, 7)7 - AIC:7985.423745806862
# Optimization terminated successfully.
#          Current function value: 3.991737
#          Iterations: 5
#          Function evaluations: 304
# SARIMA(2, 1, 2),(0, 1, 0, 7)7 - AIC:8512.39893294526
# Optimization terminated successfully.
#          Current function value: 3.743954
#          Iterations: 4
#          Function evaluations: 286
# SARIMA(2, 1, 2),(0, 1, 1, 7)7 - AIC:7986.621197488523
# Optimization terminated successfully.
#          Current function value: 3.742010
#          Iterations: 4
#          Function evaluations: 320
# SARIMA(2, 1, 2),(0, 1, 2, 7)7 - AIC:7984.481299528934
# Optimization terminated successfully.
#          Current function value: 3.905468
#          Iterations: 6
#          Function evaluations: 448
# SARIMA(2, 1, 2),(1, 1, 0, 7)7 - AIC:8330.647791020252
# Optimization terminated successfully.
#          Current function value: 3.742113
#          Iterations: 5
#          Function evaluations: 404
# SARIMA(2, 1, 2),(1, 1, 1, 7)7 - AIC:7984.6999713665
# Optimization terminated successfully.
#          Current function value: 3.741792
#          Iterations: 4
#          Function evaluations: 383
# SARIMA(2, 1, 2),(1, 1, 2, 7)7 - AIC:7986.017871176699
# Optimization terminated successfully.
#          Current function value: 3.838881
#          Iterations: 4
#          Function evaluations: 336
# SARIMA(2, 1, 2),(2, 1, 0, 7)7 - AIC:8190.815696515845
# Optimization terminated successfully.
#          Current function value: 3.742115
#          Iterations: 7
#          Function evaluations: 668
# SARIMA(2, 1, 2),(2, 1, 1, 7)7 - AIC:7986.70476971231
# Optimization terminated successfully.
#          Current function value: 3.741725
#          Iterations: 4
#          Function evaluations: 422
# SARIMA(2, 1, 2),(2, 1, 2, 7)7 - AIC:7987.874991044524

# %% [markdown]
# Elegimos aquel con menor AIC:
#
# SARIMA(1, 1, 1),(0, 1, 2, 7)7 - AIC:7980.729885903252

# %%
mod = sm.tsa.statespace.SARIMAX(train_graf,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 2, 7))
results = mod.fit(method = 'powell')
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 3.742127
#          Iterations: 3
#          Function evaluations: 177
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                             num_claims   No. Observations:                 1065
# Model:             SARIMAX(1, 1, 1)x(0, 1, [1, 2], 7)   Log Likelihood               -3985.365
# Date:                                Fri, 17 Jun 2022   AIC                           7980.730
# Time:                                        11:39:17   BIC                           8005.546
# Sample:                                    01-01-2019   HQIC                          7990.136
#                                          - 11-30-2021
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1724      0.036      4.741      0.000       0.101       0.244
# ma.L1         -0.7963      0.025    -32.084      0.000      -0.845      -0.748
# ma.S.L7       -0.9013      0.027    -32.999      0.000      -0.955      -0.848
# ma.S.L14      -0.0668      0.026     -2.540      0.011      -0.118      -0.015
# sigma2       108.0865      3.687     29.314      0.000     100.860     115.313
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                97.10
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                            -0.12
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Para hacer una valoración del ajuste de los parametros elegidos en el modelo, vamos a hacer una análisis de los residuos:
# - Residuos estandarizados: La media de los residuos fluctua en cero y tiene una varianza uniforme, por lo que la predicción no tiene sesgo
# - Histograma de la funcion de densidad: sugiere una distribucion normal, con media cero
# - Normal Q-Q: los resultados están casi en la linea recta, por lo q concluimos que siguen una tendencia a la normal y el residuo no est-a inclinado
# - Correlograma: No hay correlacion en el residuos, por lo que no hemos dejado información en ellos, por lo que el residuo es ruido blanco

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
forecast = results.predict(start = len(train_graf), 
                          end = (len(train_graf)-1) + 3 * 12,
                         typ = 'levels').rename('Forecast')
  
train_graf.plot(figsize = (20, 5), legend = True)
forecast.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
start = len(train_graf)
end = len(train_graf) + len(test_graf) - 1
  
predictions = results.predict(start, end,
                             typ = 'levels').rename("Predictions")
  
predictions.plot(legend = True)
test_graf.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Evaluación de los resultados obtenidos:

# %%
rmse(test_graf, predictions)
# Out:
# array([17.14916762, 18.5277278 , 22.47101184, 16.3256234 , 15.86005949,
#        16.64062739, 17.28903432, 17.464337  , 18.84379996, 22.93978473,
#        16.15282645, 15.76877987, 16.82197174, 17.54454354, 17.67488511,
#        19.09444458, 23.26390073, 16.26571837, 15.72473979, 16.9873017 ,
#        17.74710437, 17.88299821, 19.3495304 , 23.59125369, 16.38963351,
#        15.69293636, 17.16233568, 17.95817687, 18.09943072, 19.61118424,
#        23.92223092])

# %%
mean_squared_error(test_graf, predictions)
# Out:
# 266.43284197378534

# %%
mean_absolute_error(test_graf, predictions)
# Out:
# 13.093809926761141

# %%
mean_absolute_percentage_error(test_graf, predictions)
# Out:
# 0.2743525624796684

# %% [markdown]
# ## B. PROPHET

# %% [markdown]
# Prophet es una libreria de código abierto generada por Facebook utilizada para pronosticar datos de series de tiempo. Se basa en un modelo aditivo descomponible donde las tendencias no lineales se ajustan a la estacionalidad, y donde también podremos incluir otras variables exogenas como las vacaciones.
#
# Para mas información adjuntamos el siguiente link:
# https://facebook.github.io/prophet/docs/quick_start.html#python-api

# %%
accidents['fecha_datetime'] = pd.to_datetime(accidents['fecha_datetime'], format='%Y-%m-%d')
accidents.rename(columns={'fecha_datetime':'ds', 'num_claims':'y'}, inplace=True)

# %%
prophet_df = accidents[['ds','y']]

# %% [markdown]
# Incluimos un dataset de todos los festivos de Madrid, en el que tambien incluiremos una ventana de su efecto de -1 y 1, ya que los desplazamientos por vacaciones suelen ocurrir no solo en los dias festivos, sino tambien los dias cercanos.

# %%
#dataframe de los festivos
holidays = accidents[['ds','es_fest']]
holidays = holidays[holidays['es_fest']==True].reset_index(drop=True)
holidays.rename(columns={'es_fest':'holiday'}, inplace=True)
holidays['holiday']='Festivo'
holidays['lower_window']=-1
holidays['upper_window']=1

# %% [markdown]
# Del analisis exploratorio sabemos que el comportamiento difiere notablemente de los dias laborables a los dias del fin de semana. Para ello incluiremos un regresor que distinga de dias laborables a los que no.

# %%
#Añadimos como regresor si es fin de semana
def findesem(ds):
    date = pd.to_datetime(ds)
    if date.weekday() == 6 or date.weekday() == 5:
        return 1
    else:
        return 0

# %%
prophet_df['findesem'] = prophet_df['ds'].apply(findesem)

# %% [markdown]
# Debido al caracter excepcional y el gran impacto que  el periodo de confinamiento ha tenido sobre la variable, habría dos formas de tratarlo:
# - eliminando dicho periodo
# - aplicando un regresor extra
#
# Considero que es mejor aplicalo como un regresor, puesto que dicho DC tiene un impacto directo en los meses siguientes.

# %%
#Añadimos como regresor el periodo de cuarentena por pandemia del COVID
def covid_cuarentena(ds):
    date = pd.to_datetime(ds)
    date_covid0=pd.to_datetime('2020-03-15',  format='%Y-%m-%d')
    date_covid1=pd.to_datetime('2020-05-09',  format='%Y-%m-%d')
    if (date > date_covid0) and (date < date_covid1):
        return 1
    return 0

# %%
prophet_df['covid_cuarentena'] = prophet_df['ds'].apply(covid_cuarentena)

# %%
train = prophet_df.iloc[:(len(prophet_df)-31)]
test = prophet_df.iloc[(len(prophet_df)-31):]

# %%
# define the model
model = Prophet(holidays = holidays)
model.add_regressor('findesem')
model.add_regressor('covid_cuarentena')

# %%
# fit the model
model.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -19.6395
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2047.23    0.00113963       57.8189           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      197       2049.64    0.00026515       77.1606   3.145e-06       0.001      286  LS failed, Hessian reset
#      199       2049.65   4.28611e-05       48.4729      0.5409      0.5409      288
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       2049.71    0.00034072       68.5957           1           1      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      303       2049.73   0.000212114       76.4083   2.379e-06       0.001      480  LS failed, Hessian reset
#      399       2049.81   2.59967e-05       62.9453      0.7264      0.7264      602
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      450       2049.81   3.03089e-07        53.583      0.2903           1      676
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future = model.make_future_dataframe(periods=31, freq='D')

# %%
future['findesem'] = future['ds'].apply(findesem)
future['covid_cuarentena'] = future['ds'].apply(covid_cuarentena)

# %%
forecast = model.predict(future) 
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'trend', 'trend_lower', 'trend_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper      trend  trend_lower  \
# 1091 2021-12-27  57.385006   43.107757   70.211857  57.673695    57.596639
# 1092 2021-12-28  59.304015   46.387561   72.413460  57.717927    57.635207
# 1093 2021-12-29  59.234281   45.987152   72.442726  57.762159    57.673585
# 1094 2021-12-30  59.767186   47.283629   73.642798  57.806391    57.712874
# 1095 2021-12-31  64.599106   52.409980   78.800249  57.850623    57.747312
#
#       trend_upper
# 1091    57.762242
# 1092    57.816654
# 1093    57.867795
# 1094    57.920783
# 1095    57.975510

# %%
fig1 = model.plot(forecast)

# %%
ax=forecast.plot(x='ds',y='yhat',legend=True,label='predictions',figsize=(12,8),xlim=('2021-12-01','2021-12-31'))
test.plot(x='ds',y='y',legend=True,label='True Test Data',ax=ax, xlim=('2021-12-01','2021-12-31'))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
# changing trend points
fig=model.plot(forecast)
a=add_changepoints_to_plot(fig.gca(),model,forecast)

# %%
#Efecto de las vacaciones sobre las predicciones
forecast[(forecast['Festivo']).abs() > 0][
        ['ds', 'Festivo']][-10:]
# Out:
#              ds    Festivo
# 1043 2021-11-09 -16.199705
# 1044 2021-11-10  -4.232173
# 1069 2021-12-05  -0.704232
# 1070 2021-12-06 -16.199705
# 1071 2021-12-07  -4.936405
# 1072 2021-12-08 -16.199705
# 1073 2021-12-09  -4.232173
# 1088 2021-12-24  -0.704232
# 1089 2021-12-25 -16.199705
# 1090 2021-12-26  -4.232173

# %%
#Efecto de las vacaciones sobre las predicciones
forecast[(forecast['findesem']).abs() > 0][
        ['ds', 'findesem']][-10:]
# Out:
#              ds  findesem
# 1061 2021-11-27  2.729766
# 1062 2021-11-28  2.729766
# 1068 2021-12-04  2.729766
# 1069 2021-12-05  2.729766
# 1075 2021-12-11  2.729766
# 1076 2021-12-12  2.729766
# 1082 2021-12-18  2.729766
# 1083 2021-12-19  2.729766
# 1089 2021-12-25  2.729766
# 1090 2021-12-26  2.729766

# %% [markdown]
# Descomponemos la serie en los elementos:
# - tendencia
# - anual
# - semanal
# - efecto de las vacaciones

# %%
fig = model.plot_components(forecast)

# %% [markdown]
# Evaluación del modelo:

# %%
df_merge = pd.merge(prophet_df, forecast[['ds','yhat_lower','yhat_upper','yhat']],on='ds')
df_merge = df_merge[['ds','yhat_lower','yhat_upper','yhat','y']]
df_merge.head()
# Out:
#           ds  yhat_lower  yhat_upper       yhat   y
# 0 2019-01-01   33.451382   60.083039  45.966725  34
# 1 2019-01-02   44.260057   72.260273  58.060403  47
# 2 2019-01-03   50.659543   76.268835  63.041562  37
# 3 2019-01-04   55.030666   80.413620  68.105256  50
# 4 2019-01-05   39.603939   65.688089  53.070861  45

# %%
y_true = df_merge['y'].values
y_pred = df_merge['yhat'].values
mae_01 = mean_absolute_error(y_true, y_pred)
mape_01 = mean_absolute_percentage_error(y_true, y_pred)
print(mae_01)
print(mape_01)
# Out:
# 8.085810792813175
# 0.2543281784376655

# %% [markdown]
# Diagnóstico del modelo por medio del **Cross validation**, donde:
# - hemos cogido el parallel processes de todos los posibles, ya que nuestra muestra no es muy grande
# - los parametros son:
#     - initial: donde comienza el trainning, hemos querido descartar el año de la pandemia
#     - period: numero de dias entre los cortes
#     - horizon: periodo de forecasting, diciembre 2021

# %%
df_cv = cross_validation(model, initial='730 days', period='7 days', horizon = '31 days', parallel="processes");
# Out:
# INFO:prophet:Making 44 forecasts with cutoffs between 2021-01-02 00:00:00 and 2021-10-30 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f0df3559f10>
# Initial log joint probability = -19.638
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1423.78    0.00451074       80.5627      0.7826      0.7826      115
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1424.19   2.44736e-05       63.7672           1           1      238
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      206        1424.2   2.98933e-05       85.5301   3.358e-07       0.001      283  LS failed, Hessian reset
#      299       1424.29   2.52525e-07        70.587      0.2752      0.2752      397
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      313       1424.29   8.01135e-08       74.9765      0.7237      0.7237      418
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -34.1701
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1431.03    0.00122651       104.303       0.322       0.322      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      130       1432.23    0.00167156        179.53   2.029e-05       0.001      185  LS failed, Hessian reset
#      173       1432.38   0.000164649       68.5441   1.853e-06       0.001      276  LS failed, Hessian reset
#      199       1432.39   7.98825e-06       72.8734           1           1      318
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       1432.62   0.000275373       74.1808      0.3153           1      445
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      348       1433.07    0.00132867       76.8836   1.672e-05       0.001      558  LS failed, Hessian reset
#      399       1433.34   0.000105318       80.3834   1.227e-06       0.001      677  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      441       1433.36   7.48112e-05       96.3494   9.341e-07       0.001      769  LS failed, Hessian reset
#      499       1433.37   1.38857e-05       86.5414      0.7687      0.7687      840
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      529       1433.37    1.1843e-08       60.3754      0.1035      0.3049      885
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -20.842
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1431.95   0.000443636       65.2325      0.4126      0.4126      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1432.28    0.00453186       94.1685           1           1      243
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      224        1433.2   0.000315022       71.1381   3.718e-06       0.001      314  LS failed, Hessian reset
#      281       1433.22   1.42977e-07       89.2535           1           1      395
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -18.9187
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1447.48    0.00217898       88.8694       1.149      0.2406      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1448.43   3.01006e-06       74.9828           1           1      250
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       1448.48   2.84527e-05       86.4987      0.8952      0.8952      372
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      378       1448.75   0.000623471       85.1597   6.326e-06       0.001      549  LS failed, Hessian reset
#      399       1448.78   7.96125e-06       85.7353           1           1      575
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       1448.86   3.50674e-06       85.7328      0.6985      0.6985      699
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      534       1448.86   2.38689e-06       104.541   2.874e-08       0.001      788  LS failed, Hessian reset
#      560       1448.86   4.07594e-08        66.449      0.3379           1      824
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -19.8416
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1460.64    0.00377585       111.256      0.2053           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      179       1461.81   0.000267454       77.4073   3.366e-06       0.001      255  LS failed, Hessian reset
#      199       1462.04   0.000983961       83.4503       0.281      0.9001      278
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       96       651.172   3.78202e-07       4887.53   7.927e-11       0.001      158  LS failed, Hessian reset
#       99       651.173   7.55113e-08       4868.45      0.6528      0.6528      161
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      108       651.174   5.16082e-09       4957.03      0.3034      0.3034      175
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -15.1422
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       95       668.705    1.6214e-06       4776.19   3.225e-10       0.001      157  LS failed, Hessian reset
#       99       668.712   5.49165e-07       4800.47      0.3123           1      163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       668.716   7.37064e-09        4790.6      0.3483      0.3483      184
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -15.4139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       89       700.091   6.11558e-06        4799.7   1.136e-09       0.001      150  LS failed, Hessian reset
#       99       700.105   7.23005e-07       5067.42           1           1      162
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       700.108   7.95383e-09       3700.28           1           1      178
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -14.9783
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       718.563    1.7299e-07       5218.52           1           1      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      129       718.569   8.05447e-09       4458.25      0.3953      0.3953      168
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# Initial log joint probability = -19.8071
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#        1      -19.8071             0       575.031       1e-12       0.001       26
# Optimization terminated with error:
#   Line search failed to achieve a sufficient decrease, no more progress can be made
#
# Initial log joint probability = -312.38
# Iteration  1. Log joint probability =    447.607. Improved by 759.987.
# Iteration  2. Log joint probability =    772.046. Improved by 324.439.
# Iteration  3. Log joint probability =    892.296. Improved by 120.25.
# Iteration  4. Log joint probability =    902.973. Improved by 10.6768.
# Iteration  5. Log joint probability =    910.701. Improved by 7.72808.
# Iteration  6. Log joint probability =    916.052. Improved by 5.35098.
# Iteration  7. Log joint probability =    916.518. Improved by 0.466261.
# Iteration  8. Log joint probability =     917.12. Improved by 0.602092.
# Iteration  9. Log joint probability =    917.568. Improved by 0.447711.
# Iteration 10. Log joint probability =    917.811. Improved by 0.242943.
# Iteration 11. Log joint probability =    917.957. Improved by 0.146399.
# Iteration 12. Log joint probability =    917.963. Improved by 0.00595229.
# Iteration 13. Log joint probability =    918.031. Improved by 0.0678516.
# Iteration 14. Log joint probability =    918.048. Improved by 0.0173583.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# Iteration 15. Log joint probability =     918.08. Improved by 0.0316439.
# Iteration 16. Log joint probability =    918.081. Improved by 0.0010876.
# Initial log joint probability = -23.8901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#        1      -23.8901             0       595.057       1e-12       0.001       24
# Optimization terminated with error:
#   Line search failed to achieve a sufficient decrease, no more progress can be made
#
# Initial log joint probability = -330.247
# Iteration 17. Log joint probability =    918.101. Improved by 0.0200028.
# Iteration  1. Log joint probability =    439.257. Improved by 769.505.
# Iteration 18. Log joint probability =    918.112. Improved by 0.0110399.
# Iteration  2. Log joint probability =    780.717. Improved by 341.46.
# Iteration 19. Log joint probability =    918.115. Improved by 0.00292509.
# Iteration  3. Log joint probability =    931.658. Improved by 150.941.
# Iteration  4. Log joint probability =    932.653. Improved by 0.995671.
# Iteration 20. Log joint probability =    918.117. Improved by 0.00255271.
# Iteration  5. Log joint probability =    946.704. Improved by 14.0503.
# Iteration 21. Log joint probability =    918.118. Improved by 0.000947475.
# Iteration  6. Log joint probability =     947.93. Improved by 1.22639.
# Iteration 22. Log joint probability =    918.118. Improved by 9.51708e-05.
'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 0.01}

# %%
# define the model
model2 = Prophet(holidays = holidays,\
                 changepoint_prior_scale=best_param['changepoint_prior_scale'],\
                 seasonality_prior_scale=best_param['seasonality_prior_scale'])
model2.add_regressor('findesem')
model2.add_regressor('covid_cuarentena')

# %%
model2.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -19.6395
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2054.81     0.0233539       257.674           1           1      111
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       2064.18     0.0151944       67.9917           1           1      223
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       2066.44    0.00504356       71.4447           1           1      339
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       2068.51    0.00165451       11.5549      0.8469      0.8469      451
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      428       2069.85    0.00012629       24.6496     2.2e-06       0.001      521  LS failed, Hessian reset
#      499       2070.88   7.91444e-05       10.4509      0.5264      0.5264      604
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       2071.43    0.00106571       30.8949           1           1      723
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      666       2071.86   0.000209945       34.3237   9.741e-06       0.001      838  LS failed, Hessian reset
#      699       2072.01      0.001885       25.1694      0.6673      0.6673      873
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       2072.13    0.00207994       12.9367      0.2909           1      997
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       2072.45    0.00213466       13.6941           1           1     1104
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      974        2072.6   3.76856e-05         6.778   2.032e-06       0.001     1242  LS failed, Hessian reset
#      999       2072.61   1.98939e-05        7.9002      0.4923      0.4923     1277
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1018       2072.61   3.50293e-05       7.73164   2.258e-06       0.001     1336  LS failed, Hessian reset
#     1099       2072.63    0.00387514       17.3316           1           1     1437
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1119       2072.64   6.93686e-05        16.543   8.576e-06       0.001     1498  LS failed, Hessian reset
#     1187       2072.66    6.1439e-06       6.39381   1.031e-06       0.001     1622  LS failed, Hessian reset
#     1191       2072.66   1.93009e-06       4.73962      0.2059      0.4909     1628
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future = model2.make_future_dataframe(periods=31, freq='D')

# %%
future['findesem'] = future['ds'].apply(findesem)
future['covid_cuarentena'] = future['ds'].apply(covid_cuarentena)

# %%
forecast = model2.predict(future) 
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'trend', 'trend_lower', 'trend_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper      trend  trend_lower  \
# 1091 2021-12-27  57.166431   44.668138   69.257545  63.093779    62.451857
# 1092 2021-12-28  58.972377   47.271966   70.852351  63.143540    62.462264
# 1093 2021-12-29  58.989205   46.919620   71.811871  63.193301    62.442992
# 1094 2021-12-30  59.542868   47.164890   72.446343  63.243061    62.455970
# 1095 2021-12-31  63.916319   51.140653   75.696599  63.292822    62.461657
#
#       trend_upper
# 1091    63.791097
# 1092    63.889815
# 1093    64.003991
# 1094    64.087105
# 1095    64.180212

# %%
df_merge = pd.merge(prophet_df, forecast[['ds','yhat_lower','yhat_upper','yhat']],on='ds')
df_merge = df_merge[['ds','yhat_lower','yhat_upper','yhat','y']]
df_merge.head()
# Out:
#           ds  yhat_lower  yhat_upper       yhat   y
# 0 2019-01-01   31.013168   55.729072  43.422253  34
# 1 2019-01-02   43.241219   67.552148  55.510753  47
# 2 2019-01-03   47.743128   72.371975  60.227442  37
# 3 2019-01-04   51.528449   77.709921  64.794043  50
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -25.3886
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1990.44     0.0202195       99.8929           1           1      115
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       2001.17    0.00390369       45.1386           1           1      224
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        2007.1     0.0131012       77.6109           1           1      336
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       2008.35   0.000942916       18.1897      0.4226           1      452
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      490       2009.14    3.8476e-05        7.8517   2.323e-06       0.001      594  LS failed, Hessian reset
#      499       2009.16     0.0025993       18.7071           1           1      606
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      537       2009.26   4.72339e-05       11.2791   2.817e-06       0.001      684  LS failed, Hessian reset
#      599       2009.47    0.00300264       14.4246      0.9897      0.9897      756
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       2010.93    0.00110116        28.056           1           1      867
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      784       2011.53   0.000333242       10.8763   2.682e-05       0.001     1008  LS failed, Hessian reset
#      799       2011.55   0.000151265       13.4179       0.732       0.732     1023
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       2011.75     0.0129024       23.8973      0.7029      0.7029     1142
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      906       2011.81   0.000170488       39.9807   2.859e-06       0.001     1195  LS failed, Hessian reset
#      993        2012.1   4.56747e-05       11.1758   5.355e-06       0.001     1332  LS failed, Hessian reset
#      999       2012.11   9.88889e-05       6.99486      0.7721      0.7721     1339
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1061       2012.14   4.55442e-07       7.59024      0.1658      0.6278     1420
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon         mse       rmse       mae      mape     mdape     smape  \
# 0  4 days  106.082376  10.299630  7.576589  0.294242  0.130439  0.174906
# 1  5 days  115.304345  10.737986  7.986099  0.232331  0.134493  0.175026
# 2  6 days  133.796590  11.567048  8.868247  0.217039  0.150770  0.182161
# 3  7 days  159.739330  12.638803  9.709373  0.287359  0.147665  0.210158
# 4  8 days  166.552163  12.905509  9.995538  0.564756  0.185412  0.235854
#
#    coverage
# 0  0.838904
# 1  0.820187
# 2  0.781417
# 3  0.722594
# 4  0.693182

# %%
fig = plot_cross_validation_metric(df_cv, metric='mape')
plt.ylim(0,2);

# %% [markdown]
# ## C. DEEP LEARNING: RED NEURONAL

# %% [markdown]
# **CONSIDERANDO UNICAMENTE LOS ACCIDENTES DE LOS 7 DIAS ANTERIORES**

# %% [markdown]
# Generamos el dataset con el que trabajaremos, de los que solo necesitamos fecha y frecuencia. Tenemos que asegurarnos que los valores son float.

# %%
red_neu_1var_df = accidents[['ds','y']]

# %%
red_neu_1var_df.set_index('ds', inplace = True)

# %%
values = red_neu_1var_df.values
values = values.astype('float32')

# %% [markdown]
# Como función de activación utilizamos tangente hiperbólica puesto que utilizaremos valores entre -1 y 1

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1)
scaled = scaler.fit_transform(values)

# %% [markdown]
# Escribimos la siguiente función para pasar el problema a supervisado : entrenaremos el dataset con backpropagation, entendiendo la ponderación en el reparto del error para cada una de las neuronas de la red

# %%
# convertimos la serie a supervisado
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# Consideramos que la red neuronal va a tener 7 neuronas, debido a la estacionalidad semanal que sabemos muestran los datos

# %%
#nº vectores
PASOS = 7

# %%
# dataframe como supervisado
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7   -0.445378  -0.226891  -0.394958  -0.176471  -0.260504  -0.361345
# 8   -0.226891  -0.394958  -0.176471  -0.260504  -0.361345  -0.361345
# 9   -0.394958  -0.176471  -0.260504  -0.361345  -0.361345   0.142857
# 10  -0.176471  -0.260504  -0.361345  -0.361345   0.142857   0.260504
# 11  -0.260504  -0.361345  -0.361345   0.142857   0.260504  -0.109244
#
#     var1(t-1)   var1(t)
# 7   -0.361345  0.142857
# 8    0.142857  0.260504
# 9    0.260504 -0.109244
# 10  -0.109244  0.394958
# 11   0.394958 -0.042017

# %% [markdown]
# Preparamos los datos entre df_train y df_test, donde el test será de los últimos 31 días; y a su vez, usaremos como entradas las columnas encabezadas como var1(t-7) a (t-1) y nuestra salida el var1(t).

# %%
# separamos el dataframe entre train y test, para el ultimo mes
values = reframed.values
n_train_days = 1096 - (31+PASOS)
train = values[:n_train_days, :]
test = values[n_train_days:, :]

# %%
# separamos inputs de outputs, tanto de train como de test
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]

# %%
# reajustamos train y test [nºobservaciones, variables, pasos]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (1058, 1, 7) (1058,) (31, 1, 7) (31,)

# %% [markdown]
# Utilizaremos como optimizador Adam y métrica de pérdida el Mean Absolute Error

# %%
def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %% [markdown]
# Vemos que el modelo va aprendiendo porque va bajando con los EPOCHS.

# %%
EPOCHS=40

model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# 2022-06-17 11:56:25.764863: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-17 11:56:25.765558: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-17 11:56:25.767323: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (kschool-vm): /proc/driver/nvidia/version does not exist
# 2022-06-17 11:56:25.776241: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1, 7)              56
#
#  flatten (Flatten)           (None, 7)                 0
#
#  dense_1 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 152/152 [==============================] - 1s 3ms/step - loss: 0.1899 - mse: 0.0581 - val_loss: 0.1982 - val_mse: 0.0650
# Epoch 2/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1639 - mse: 0.0439 - val_loss: 0.1981 - val_mse: 0.0622
# Epoch 3/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1571 - mse: 0.0408 - val_loss: 0.2025 - val_mse: 0.0626
# Epoch 4/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1543 - mse: 0.0397 - val_loss: 0.2037 - val_mse: 0.0627
# Epoch 5/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1526 - mse: 0.0395 - val_loss: 0.2055 - val_mse: 0.0624
# Epoch 6/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1518 - mse: 0.0389 - val_loss: 0.2056 - val_mse: 0.0634
# Epoch 7/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1514 - mse: 0.0387 - val_loss: 0.2051 - val_mse: 0.0633
# Epoch 8/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1506 - mse: 0.0384 - val_loss: 0.2047 - val_mse: 0.0621
# Epoch 9/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1506 - mse: 0.0385 - val_loss: 0.2059 - val_mse: 0.0630
# Epoch 10/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1502 - mse: 0.0382 - val_loss: 0.2071 - val_mse: 0.0640
# Epoch 11/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1494 - mse: 0.0382 - val_loss: 0.2035 - val_mse: 0.0633
# Epoch 12/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1494 - mse: 0.0379 - val_loss: 0.2045 - val_mse: 0.0634
# Epoch 13/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1490 - mse: 0.0378 - val_loss: 0.2073 - val_mse: 0.0662
# Epoch 14/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1488 - mse: 0.0375 - val_loss: 0.2052 - val_mse: 0.0631
# Epoch 15/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1481 - mse: 0.0380 - val_loss: 0.2040 - val_mse: 0.0632
# Epoch 16/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1482 - mse: 0.0375 - val_loss: 0.2057 - val_mse: 0.0641
# Epoch 17/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1478 - mse: 0.0376 - val_loss: 0.2072 - val_mse: 0.0643
# Epoch 18/40
# 152/152 [==============================] - 0s 1ms/step - loss: 0.1475 - mse: 0.0373 - val_loss: 0.2032 - val_mse: 0.0636
# Epoch 19/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1477 - mse: 0.0375 - val_loss: 0.2011 - val_mse: 0.0629
# Epoch 20/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1476 - mse: 0.0371 - val_loss: 0.2052 - val_mse: 0.0646
# Epoch 21/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1473 - mse: 0.0372 - val_loss: 0.2072 - val_mse: 0.0639
# Epoch 22/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1470 - mse: 0.0374 - val_loss: 0.2073 - val_mse: 0.0643
# Epoch 23/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1472 - mse: 0.0371 - val_loss: 0.2073 - val_mse: 0.0640
# Epoch 24/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1467 - mse: 0.0370 - val_loss: 0.2067 - val_mse: 0.0635
# Epoch 25/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1464 - mse: 0.0366 - val_loss: 0.2067 - val_mse: 0.0646
# Epoch 26/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1469 - mse: 0.0371 - val_loss: 0.2058 - val_mse: 0.0646
# Epoch 27/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1462 - mse: 0.0369 - val_loss: 0.2061 - val_mse: 0.0635
# Epoch 28/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1463 - mse: 0.0366 - val_loss: 0.2053 - val_mse: 0.0632
# Epoch 29/40
# 152/152 [==============================] - 1s 4ms/step - loss: 0.1464 - mse: 0.0370 - val_loss: 0.2051 - val_mse: 0.0639
# Epoch 30/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1460 - mse: 0.0366 - val_loss: 0.2079 - val_mse: 0.0645
# Epoch 31/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1461 - mse: 0.0368 - val_loss: 0.2056 - val_mse: 0.0641
# Epoch 32/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1461 - mse: 0.0367 - val_loss: 0.2070 - val_mse: 0.0648
# Epoch 33/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1460 - mse: 0.0368 - val_loss: 0.2047 - val_mse: 0.0643
# Epoch 34/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1462 - mse: 0.0366 - val_loss: 0.2051 - val_mse: 0.0638
# Epoch 35/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1458 - mse: 0.0367 - val_loss: 0.2064 - val_mse: 0.0656
# Epoch 36/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1459 - mse: 0.0367 - val_loss: 0.2054 - val_mse: 0.0647
# Epoch 37/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1460 - mse: 0.0367 - val_loss: 0.2056 - val_mse: 0.0645
# Epoch 38/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1461 - mse: 0.0366 - val_loss: 0.2044 - val_mse: 0.0634
# Epoch 39/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1461 - mse: 0.0364 - val_loss: 0.2065 - val_mse: 0.0643
# Epoch 40/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1457 - mse: 0.0366 - val_loss: 0.2089 - val_mse: 0.0665

# %% [markdown]
# Representamos graficamente las predicciones y los datos reales de los ultimos 31 dias.

# %%
results=model.predict(x_val)
print( len(results) )
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 [==============================] - 0s 139ms/step
# 31

# %% [markdown]
# Vemos que el LOSS tanto en el conjunto de train como el de Validate van DC, esto indica que el modelo está aprendiendo y a su vez pareciera no haber overfitting, pues las curvas de train y validate son distintas.

# %%
plt.plot(history.history['loss'],c='r')
plt.title('loss')
plt.plot(history.history['val_loss'], c='g')
plt.title('validate loss')
plt.show()

# %% [markdown]
# Para calcular el Acuracy utilizaremos Mean Squared Error.

# %%
plt.title('Accuracy')
plt.plot(history.history['mse'])
plt.show()

# %%
rmse(test_graf, predictions)
# Out:
# array([17.14916762, 18.5277278 , 22.47101184, 16.3256234 , 15.86005949,
#        16.64062739, 17.28903432, 17.464337  , 18.84379996, 22.93978473,
#        16.15282645, 15.76877987, 16.82197174, 17.54454354, 17.67488511,
#        19.09444458, 23.26390073, 16.26571837, 15.72473979, 16.9873017 ,
#        17.74710437, 17.88299821, 19.3495304 , 23.59125369, 16.38963351,
#        15.69293636, 17.16233568, 17.95817687, 18.09943072, 19.61118424,
#        23.92223092])

# %%
compara = pd.DataFrame(np.array([y_val, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = compara2['real'] - compara2['prediccion']
compara2.head()
# Out:
#     real  prediccion  diferencia
# 0   83.0   63.393269   19.606731
# 1   76.0   70.757019    5.242981
# 2  105.0   70.518639   34.481361
# 3   49.0   80.430206  -31.430206
# 4   33.0   52.611965  -19.611965

# %% [markdown]
# Vamos a comparar los datos

# %%
compara2.describe()
# Out:
#              real  prediccion  diferencia
# count   31.000000   31.000000   31.000000
# mean    57.290321   60.980145   -3.689818
# std     15.925228    6.900654   15.139838
# min     33.000000   47.364883  -31.430206
# 25%     48.500000   56.218933  -14.257746
# 50%     55.000000   60.709167   -3.271912
# 75%     69.500000   63.488083    7.334524
# max    105.000000   80.430206   34.481361

# %%
compara2['real'].plot()
compara2['prediccion'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Evaluación del modelo:

# %%
mean_squared_error(compara2['real'], compara2['prediccion'])
# Out:
# 235.43541

# %%
rmse(compara2['real'], compara2['prediccion'])
# Out:
# 15.3439045

# %%
mean_absolute_error(compara2['real'], compara2['prediccion'])
# Out:
# 12.432302

# %%
mean_absolute_percentage_error(compara2['real'], compara2['prediccion'])
# Out:
# 0.2470465

# %% [markdown]
# **CONSIDERANDO LAS VARIABLES ACCIDENTES DE LOS 7 DIAS ANTERIORES, MES Y DÍA DE LA SEMANA**

# %%
red_neu_3var_df = accidents[['ds','y','mes','dia_sem_code']]

# %%
red_neu_3var_df.set_index('ds', inplace = True)

# %%
values = red_neu_3var_df['y'].values
values = values.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1)
scaled = scaler.fit_transform(values)

# %%
red_neu_3var_df['scaled'] = scaled
scaledMerge=red_neu_3var_df.drop('y',axis=1)

# %%
reframed = series_to_supervised(scaledMerge, PASOS, 1)
reframed.head()
# Out:
#             var1(t-7)  var2(t-7)  var3(t-7)  var1(t-6)  var2(t-6)  var3(t-6)  \
# ds
# 2019-01-08        1.0        2.0  -0.445378        1.0        3.0  -0.226891
# 2019-01-09        1.0        3.0  -0.226891        1.0        4.0  -0.394958
# 2019-01-10        1.0        4.0  -0.394958        1.0        5.0  -0.176471
# 2019-01-11        1.0        5.0  -0.176471        1.0        6.0  -0.260504
# 2019-01-12        1.0        6.0  -0.260504        1.0        7.0  -0.361345
#
#             var1(t-5)  var2(t-5)  var3(t-5)  var1(t-4)  ...  var3(t-3)  \
# ds                                                      ...
# 2019-01-08        1.0        4.0  -0.394958        1.0  ...  -0.260504
# 2019-01-09        1.0        5.0  -0.176471        1.0  ...  -0.361345
# 2019-01-10        1.0        6.0  -0.260504        1.0  ...  -0.361345
# 2019-01-11        1.0        7.0  -0.361345        1.0  ...   0.142857
# 2019-01-12        1.0        1.0  -0.361345        1.0  ...   0.260504
#
#             var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# ds
# 2019-01-08        1.0        7.0  -0.361345        1.0        1.0  -0.361345
# 2019-01-09        1.0        1.0  -0.361345        1.0        2.0   0.142857
# 2019-01-10        1.0        2.0   0.142857        1.0        3.0   0.260504
# 2019-01-11        1.0        3.0   0.260504        1.0        4.0  -0.109244
# 2019-01-12        1.0        4.0  -0.109244        1.0        5.0   0.394958
#
#             var1(t)  var2(t)   var3(t)
# ds
# 2019-01-08        1        2  0.142857
# 2019-01-09        1        3  0.260504
# 2019-01-10        1        4 -0.109244
# 2019-01-11        1        5  0.394958
# 2019-01-12        1        6 -0.042017
#
# [5 rows x 24 columns]

# %%
newReframed=reframed.drop(['var1(t)','var2(t)'],axis=1)
print(newReframed.shape)
newReframed.head()
# Out:
# (1089, 22)
#             var1(t-7)  var2(t-7)  var3(t-7)  var1(t-6)  var2(t-6)  var3(t-6)  \
# ds
# 2019-01-08        1.0        2.0  -0.445378        1.0        3.0  -0.226891
# 2019-01-09        1.0        3.0  -0.226891        1.0        4.0  -0.394958
# 2019-01-10        1.0        4.0  -0.394958        1.0        5.0  -0.176471
# 2019-01-11        1.0        5.0  -0.176471        1.0        6.0  -0.260504
# 2019-01-12        1.0        6.0  -0.260504        1.0        7.0  -0.361345
#
#             var1(t-5)  var2(t-5)  var3(t-5)  var1(t-4)  ...  var1(t-3)  \
# ds                                                      ...
# 2019-01-08        1.0        4.0  -0.394958        1.0  ...        1.0
# 2019-01-09        1.0        5.0  -0.176471        1.0  ...        1.0
# 2019-01-10        1.0        6.0  -0.260504        1.0  ...        1.0
# 2019-01-11        1.0        7.0  -0.361345        1.0  ...        1.0
# 2019-01-12        1.0        1.0  -0.361345        1.0  ...        1.0
#
#             var2(t-3)  var3(t-3)  var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  \
# ds
# 2019-01-08        6.0  -0.260504        1.0        7.0  -0.361345        1.0
# 2019-01-09        7.0  -0.361345        1.0        1.0  -0.361345        1.0
# 2019-01-10        1.0  -0.361345        1.0        2.0   0.142857        1.0
# 2019-01-11        2.0   0.142857        1.0        3.0   0.260504        1.0
# 2019-01-12        3.0   0.260504        1.0        4.0  -0.109244        1.0
#
#             var2(t-1)  var3(t-1)   var3(t)
# ds
# 2019-01-08        1.0  -0.361345  0.142857
# 2019-01-09        2.0   0.142857  0.260504
# 2019-01-10        3.0   0.260504 -0.109244
# 2019-01-11        4.0  -0.109244  0.394958
# 2019-01-12        5.0   0.394958 -0.042017
#
# [5 rows x 22 columns]

# %%
# split into train and test sets
values = newReframed.values
n_train_days = 1096 - (31+PASOS)
train = values[:n_train_days, :]
test = values[n_train_days:, :]

# %%
# split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]

# %%
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (1058, 1, 21) (1058,) (31, 1, 21) (31,)

# %%
def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(PASOS, input_shape=(1,PASOS*3),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1, 7)              154
#
#  flatten_1 (Flatten)         (None, 7)                 0
#
#  dense_3 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
#
40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1491 - mse: 0.0385 - val_loss: 0.1485 - val_mse: 0.0341
# Epoch 34/40
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1511 - mse: 0.0390 - val_loss: 0.1697 - val_mse: 0.0413
# Epoch 35/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1471 - mse: 0.0370 - val_loss: 0.1507 - val_mse: 0.0367
# Epoch 36/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1468 - mse: 0.0364 - val_loss: 0.1589 - val_mse: 0.0372
# Epoch 37/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1436 - mse: 0.0359 - val_loss: 0.1468 - val_mse: 0.0326
# Epoch 38/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1431 - mse: 0.0358 - val_loss: 0.1711 - val_mse: 0.0437
# Epoch 39/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1432 - mse: 0.0356 - val_loss: 0.1707 - val_mse: 0.0432
# Epoch 40/40
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1404 - mse: 0.0343 - val_loss: 0.1596 - val_mse: 0.0371

# %%
results=model.predict(x_val)
print( len(results) )
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 [==============================] - 0s 80ms/step
# 31

# %%
plt.ylim(0.12, 0.35)
plt.plot(history.history['loss'],c='r')
plt.title('loss')
plt.plot(history.history['val_loss'],c='g')
plt.title('validate loss')
plt.show()

# %%
plt.ylim(0.01, 0.18)
plt.title('Accuracy')
plt.plot(history.history['mse'])
plt.show()

# %%
compara = pd.DataFrame(np.array([y_val, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = compara2['real'] - compara2['prediccion']
compara2.head(10)
# Out:
#          real  prediccion  diferencia
# 0   82.999998   65.146546   17.853452
# 1   75.999999   60.570547   15.429452
# 2  105.000003   87.244167   17.755836
# 3   49.000002   61.366896  -12.366895
# 4   33.000000   57.730508  -24.730508
# 5   44.999999   55.722143  -10.722145
# 6   52.000001   58.550320   -6.550318
# 7   48.000002   58.672326  -10.672325
# 8   49.000002   55.071456   -6.071454
# 9   70.999999   57.864807   13.135192

# %%
compara2.describe()
# Out:
#              real  prediccion  diferencia
# count   31.000000   31.000000   31.000000
# mean    57.290323   57.452229   -0.161906
# std     15.925228    8.008341   11.651838
# min     33.000000   46.030033  -24.730508
# 25%     48.500002   54.229322   -6.310886
# 50%     55.000001   57.864807    2.386179
# 75%     69.499999   60.117269    9.067767
# max    105.000003   87.244167   17.853452

# %%
compara2['real'].plot()
compara2['prediccion'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Evaluación del modelo:

# %%
mean_squared_error(compara2['real'], compara2['prediccion'])
# Out:
# 131.4120197929412

# %%
rmse(compara2['real'], compara2['prediccion'])
# Out:
# 11.463508180000623

# %%
mean_absolute_error(compara2['real'], compara2['prediccion'])
# Out:
# 9.496229315110636

# %%
mean_absolute_percentage_error(compara2['real'], compara2['prediccion'])
# Out:
# 0.1871974060413675

# %% [markdown]
# **CONSIDERANDO LAS VARIABLES ACCIDENTES DE LOS 7 DIAS ANTERIORES Y EMBEDDINGS MES Y DÍA DE LA SEMANA**

# %%
red_neu_3var_df = accidents[['ds','y','mes','dia_sem_code']]

# %%
red_neu_3var_df.set_index('ds', inplace = True)

# %%
red_neu_emb_df = accidents[['ds','y']]

# %%
red_neu_emb_df.set_index('ds', inplace = True)

# %%
# load dataset
values = red_neu_emb_df['y'].values

# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))

values=values.reshape(-1, 1) 

scaled = scaler.fit_transform(values)

reframed = series_to_supervised(scaled, PASOS, 1)
reframed.reset_index(inplace=True, drop=True)

contador=0
reframed['weekday']=red_neu_3var_df['dia_sem_code']
reframed['month']=red_neu_3var_df['mes']

for i in range(reframed.index[0],reframed.index[-1]):
    reframed['weekday'].loc[contador]=red_neu_3var_df['dia_sem_code'][i+8]
    reframed['month'].loc[contador]=red_neu_3var_df['mes'][i+8]
    contador=contador+1
reframed.shape
# Out:
# (1089, 10)

# %%
reordenado=reframed[ ['weekday','month','var1(t-7)','var1(t-6)','var1(t-5)','var1(t-4)','var1(t-3)',\
                      'var1(t-2)','var1(t-1)','var1(t)'] ]
reordenado.dropna(inplace=True)
reordenado.head()
# Out:
#    weekday  month  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  \
# 0      3.0    1.0  -0.445378  -0.226891  -0.394958  -0.176471  -0.260504
# 1      4.0    1.0  -0.226891  -0.394958  -0.176471  -0.260504  -0.361345
# 2      5.0    1.0  -0.394958  -0.176471  -0.260504  -0.361345  -0.361345
# 3      6.0    1.0  -0.176471  -0.260504  -0.361345  -0.361345   0.142857
# 4      7.0    1.0  -0.260504  -0.361345  -0.361345   0.142857   0.260504
#
#    var1(t-2)  var1(t-1)   var1(t)
# 0  -0.361345  -0.361345  0.142857
# 1  -0.361345   0.142857  0.260504
# 2   0.142857   0.260504 -0.109244
# 3   0.260504  -0.109244  0.394958
# 4  -0.109244   0.394958 -0.042017

# %%
training_data = reordenado.drop('var1(t)',axis=1)#.values
target_data=reordenado['var1(t)']
#training_data.head()
valid_data = training_data[1086-31:1086]
valid_target=target_data[1086-31:1086]

training_data = training_data[0:1086]
target_data=target_data[0:1086]
print(training_data.shape,target_data.shape,valid_data.shape,valid_target.shape)
#training_data.head()
# Out:
# (1086, 9) (1086,) (31, 9) (31,)

# %%
def crear_modeloEmbeddings():
    emb_dias = 2 #tamanio profundidad de embeddings
    emb_meses = 4
    

    in_dias = Input(shape=[1], name = 'dias')
    emb_dias = Embedding(7+1, emb_dias)(in_dias)
    in_meses = Input(shape=[1], name = 'meses')
    emb_meses = Embedding(12+1, emb_meses)(in_meses)
    
    
    in_cli = Input(shape=[PASOS], name = 'cli')

    fe = concatenate([(emb_dias), (emb_meses)])

    x = Flatten()(fe)
    x = Dense(PASOS,activation='tanh')(x)
    outp = Dense(1,activation='tanh')(x)
    model = Model(inputs=[in_dias,in_meses,in_cli], outputs=outp)

    model.compile(loss='mean_absolute_error', 
                  optimizer='adam',
                  metrics=['MSE'])

    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloEmbeddings()

continuas=training_data[['var1(t-7)','var1(t-6)','var1(t-5)','var1(t-4)','var1(t-3)','var1(t-2)','var1(t-1)']]
valid_continuas=valid_data[['var1(t-7)','var1(t-6)','var1(t-5)','var1(t-4)','var1(t-3)','var1(t-2)','var1(t-1)']]

history=model.fit([training_data['weekday'],training_data['month'],continuas], target_data, epochs=EPOCHS
                 ,validation_data=([valid_data['weekday'],valid_data['month'],valid_continuas],valid_target))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dias (InputLayer)              [(None, 1)]          0           []
#
#  meses (InputLayer)             [(None, 1)]          0           []
#
#  embedding (Embedding)          (None, 1, 2)         16          ['dias[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 4)         52          ['meses[0][0]']
#
#  concatenate (Concatenate)      (None, 1, 6)         0           ['embedding[0][0]',
#                                                                   'embedding_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 6)            0           ['concatenate[0][0]']
#
#  dense_4 (Dense)                (None, 7)            49          ['flatten_2[0][0]']
#
#  cli (InputLayer)               [(None, 7)]          0           []
#
#  dense_5 (Dense)                (None, 1)            8           ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 125
# Trainable params: 125
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/40
# 34/34 [==============================] - 1s 6ms/step - loss: 0.2605 - MSE: 0.1097 - val_loss: 0.1983 - val_MSE: 0.0714
# Epoch 2/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2370 - MSE: 0.0893 - val_loss: 0.1933 - val_MSE: 0.0699
# Epoch 3/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2245 - MSE: 0.0814 - val_loss: 0.1739 - val_MSE: 0.0568
# Epoch 4/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2133 - MSE: 0.0759 - val_loss: 0.1601 - val_MSE: 0.0480
# Epoch 5/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2080 - MSE: 0.0733 - val_loss: 0.1567 - val_MSE: 0.0449
# Epoch 6/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2070 - MSE: 0.0735 - val_loss: 0.1503 - val_MSE: 0.0415
# Epoch 7/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2058 - MSE: 0.0734 - val_loss: 0.1515 - val_MSE: 0.0410
# Epoch 8/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2057 - MSE: 0.0740 - val_loss: 0.1629 - val_MSE: 0.0450
# Epoch 9/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2061 - MSE: 0.0735 - val_loss: 0.1536 - val_MSE: 0.0419
# Epoch 10/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2057 - MSE: 0.0738 - val_loss: 0.1606 - val_MSE: 0.0437
# Epoch 11/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2054 - MSE: 0.0736 - val_loss: 0.1525 - val_MSE: 0.0411
# Epoch 12/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2059 - MSE: 0.0739 - val_loss: 0.1548 - val_MSE: 0.0420
# Epoch 13/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2055 - MSE: 0.0736 - val_loss: 0.1559 - val_MSE: 0.0425
# Epoch 14/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2053 - MSE: 0.0734 - val_loss: 0.1547 - val_MSE: 0.0422
# Epoch 15/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2058 - MSE: 0.0735 - val_loss: 0.1565 - val_MSE: 0.0426
# Epoch 16/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2054 - MSE: 0.0736 - val_loss: 0.1559 - val_MSE: 0.0428
# Epoch 17/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2058 - MSE: 0.0739 - val_loss: 0.1551 - val_MSE: 0.0423
# Epoch 18/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2054 - MSE: 0.0735 - val_loss: 0.1561 - val_MSE: 0.0426
# Epoch 19/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2053 - MSE: 0.0738 - val_loss: 0.1541 - val_MSE: 0.0418
# Epoch 20/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2054 - MSE: 0.0738 - val_loss: 0.1544 - val_MSE: 0.0421
# Epoch 21/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2051 - MSE: 0.0736 - val_loss: 0.1565 - val_MSE: 0.0426
# Epoch 22/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2054 - MSE: 0.0741 - val_loss: 0.1608 - val_MSE: 0.0441
# Epoch 23/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2057 - MSE: 0.0734 - val_loss: 0.1518 - val_MSE: 0.0413
# Epoch 24/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2059 - MSE: 0.0734 - val_loss: 0.1516 - val_MSE: 0.0412
# Epoch 25/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2054 - MSE: 0.0738 - val_loss: 0.1569 - val_MSE: 0.0431
# Epoch 26/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2050 - MSE: 0.0736 - val_loss: 0.1590 - val_MSE: 0.0436
# Epoch 27/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2056 - MSE: 0.0738 - val_loss: 0.1510 - val_MSE: 0.0413
# Epoch 28/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2055 - MSE: 0.0736 - val_loss: 0.1530 - val_MSE: 0.0416
# Epoch 29/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2052 - MSE: 0.0732 - val_loss: 0.1562 - val_MSE: 0.0429
# Epoch 30/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2053 - MSE: 0.0739 - val_loss: 0.1586 - val_MSE: 0.0435
# Epoch 31/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2055 - MSE: 0.0735 - val_loss: 0.1559 - val_MSE: 0.0427
# Epoch 32/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2052 - MSE: 0.0737 - val_loss: 0.1555 - val_MSE: 0.0425
# Epoch 33/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2053 - MSE: 0.0732 - val_loss: 0.1550 - val_MSE: 0.0422
# Epoch 34/40
# 34/34 [==============================] - 0s 6ms/step - loss: 0.2055 - MSE: 0.0736 - val_loss: 0.1537 - val_MSE: 0.0418
# Epoch 35/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2055 - MSE: 0.0739 - val_loss: 0.1570 - val_MSE: 0.0428
# Epoch 36/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2054 - MSE: 0.0736 - val_loss: 0.1575 - val_MSE: 0.0428
# Epoch 37/40
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2054 - MSE: 0.0733 - val_loss: 0.1545 - val_MSE: 0.0424
# Epoch 38/40
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2057 - MSE: 0.0739 - val_loss: 0.1538 - val_MSE: 0.0417
# Epoch 39/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2053 - MSE: 0.0733 - val_loss: 0.1502 - val_MSE: 0.0405
# Epoch 40/40
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2056 - MSE: 0.0741 - val_loss: 0.1552 - val_MSE: 0.0424

# %%
results=model.predict([valid_data['weekday'],valid_data['month'],valid_continuas])
print( len(results) )
plt.scatter(range(len(valid_target)),valid_target,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 [==============================] - 0s 93ms/step
# 31

# %%
plt.plot(history.history['loss'])
plt.title('loss')
plt.plot(history.history['val_loss'])
plt.title('validate loss')
plt.show()

# %%
plt.title('Accuracy')
plt.plot(history.history['MSE'])
plt.show()

# %%
compara = pd.DataFrame(np.array([valid_target, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = compara2['real'] - compara2['prediccion']
compara2.head(12)
# Out:
#      real  prediccion  diferencia
# 0    51.0   46.389351    4.610649
# 1    62.0   57.509575    4.490425
# 2    62.0   57.675747    4.324253
# 3    83.0   57.705345   25.294655
# 4    76.0   60.864342   15.135658
# 5   105.0   66.796509   38.203491
# 6    49.0   48.981411    0.018589
# 7    33.0   43.801643  -10.801643
# 8    45.0   54.709343   -9.709343
# 9    52.0   57.675747   -5.675747
# 10   48.0   57.705345   -9.705345
# 11   49.0   60.864342  -11.864342

# %%
compara2['real'].plot()
compara2['prediccion'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Evaluación del modelo:

# %%
mean_squared_error(compara2['real'], compara2['prediccion'])
# Out:
# 150.25497

# %%
rmse(compara2['real'], compara2['prediccion'])
# Out:
# 12.2578535

# %%
mean_absolute_error(compara2['real'], compara2['prediccion'])
# Out:
# 9.234274

# %%
mean_absolute_percentage_error(compara2['real'], compara2['prediccion'])
# Out:
# 0.16113621

# %% [markdown]
# De los tres modelos de redes neuronales aplicados consideramos que el que mejores predicciones podrá generar será el que CONSIDERA LAS VARIABLES ACCIDENTES DE LOS 7 DIAS ANTERIORES Y EMBEDDINGS MES Y DÍA DE LA SEMANA  ya que es el que mejores medidas de medición tiene.

# %% [markdown]
# ## PREDICCIÓN

# %%
ultimosDias = red_neu_3var_df['2021-12-16':'2021-12-31']
ultimosDias
# Out:
#              y  mes  dia_sem_code
# ds
# 2021-12-16  55   12             4
# 2021-12-17  70   12             5
# 2021-12-18  49   12             6
# 2021-12-19  50   12             7
# 2021-12-20  54   12             1
# 2021-12-21  61   12             2
# 2021-12-22  72   12             3
# 2021-12-23  63   12             4
# 2021-12-24  76   12             5
# 2021-12-25  36   12             6
# 2021-12-26  49   12             7
# 2021-12-27  56   12             1
# 2021-12-28  34   12             2
# 2021-12-29  37   12             3
# 2021-12-30  42   12             4
# 2021-12-31  44   12             5

# %%
# load dataset
values = ultimosDias['y'].values

# ensure all data is float
values = values.astype('float32')
# normalize features
#scaler = MinMaxScaler(feature_range=(-1, 1))

values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension

scaled = scaler.fit_transform(values)

reframed = series_to_supervised(scaled, PASOS, 1)
reframed.reset_index(inplace=True, drop=True)

contador=0
reframed['weekday']=ultimosDias['dia_sem_code']
reframed['month']=ultimosDias['mes']

for i in range(reframed.index[0],reframed.index[-1]):
    reframed['weekday'].loc[contador]=ultimosDias['dia_sem_code'][i+8]
    reframed['month'].loc[contador]=ultimosDias['mes'][i+8]
    contador=contador+1
reframed.head()

reordenado=reframed[ ['weekday','month','var1(t-7)','var1(t-6)','var1(t-5)','var1(t-4)','var1(t-3)','var1(t-2)','var1(t-1)'] ]
reordenado.dropna(inplace=True)
reordenado
# Out:
#    weekday  month  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  \
# 0      5.0   12.0   0.000000   0.714286  -0.285714  -0.238095  -0.047619
# 1      6.0   12.0   0.714286  -0.285714  -0.238095  -0.047619   0.285714
# 2      7.0   12.0  -0.285714  -0.238095  -0.047619   0.285714   0.809524
# 3      1.0   12.0  -0.238095  -0.047619   0.285714   0.809524   0.380952
# 4      2.0   12.0  -0.047619   0.285714   0.809524   0.380952   1.000000
# 5      3.0   12.0   0.285714   0.809524   0.380952   1.000000  -0.904762
# 6      4.0   12.0   0.809524   0.380952   1.000000  -0.904762  -0.285714
# 7      5.0   12.0   0.380952   1.000000  -0.904762  -0.285714   0.047619
#
#    var1(t-2)  var1(t-1)
# 0   0.285714   0.809524
# 1   0.809524   0.380952
# 2   0.380952   1.000000
# 3   1.000000  -0.904762
# 4  -0.904762  -0.285714
# 5  -0.285714   0.047619
# 6   0.047619  -1.000000
# 7  -1.000000  -0.857143

# %%
values = reordenado.values
x_test = values[5:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
print(x_test.shape)
print(x_test)
ultDiaSemana = reordenado.weekday[len(reordenado.index)-1]
ultDiaSemana
# Out:
# (3, 1, 9)
# [[[ 3.         12.          0.28571439  0.80952382  0.38095236
#     1.         -0.90476191 -0.28571415  0.0476191 ]]
#
#  [[ 4.         12.          0.80952382  0.38095236  1.
#    -0.90476191 -0.28571415  0.0476191  -1.        ]]
#
#  [[ 5.         12.          0.38095236  1.         -0.90476191
#    -0.28571415  0.0476191  -1.         -0.85714281]]]
# 5.0

# %%
model = crear_modeloEmbeddings()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dias (InputLayer)              [(None, 1)]          0           []
#
#  meses (InputLayer)             [(None, 1)]          0           []
#
#  embedding_2 (Embedding)        (None, 1, 2)         16          ['dias[0][0]']
#
#  embedding_3 (Embedding)        (None, 1, 4)         52          ['meses[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 6)         0           ['embedding_2[0][0]',
#                                                                   'embedding_3[0][0]']
#
#  flatten_3 (Flatten)            (None, 6)            0           ['concatenate_1[0][0]']
#
#  dense_6 (Dense)                (None, 7)            49          ['flatten_3[0][0]']
#
#  cli (InputLayer)               [(None, 7)]          0           []
#
#  dense_7 (Dense)                (None, 1)            8           ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 125
# Trainable params: 125
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def agregarNuevoValor(x_test,nuevoValor,ultDiaSemana):
    for i in range(x_test.shape[2]-3):
        x_test[0][0][i+2] = x_test[0][0][i+3]
    ultDiaSemana=ultDiaSemana+1
    if ultDiaSemana>6:
        ultDiaSemana=0
    x_test[0][0][0]=ultDiaSemana
    x_test[0][0][1]=12
    x_test[0][0][x_test.shape[2]-1]=nuevoValor
    return x_test,ultDiaSemana

# %%
results=[]
for i in range(7):
    dia=np.array([x_test[0][0][0]])
    mes=np.array([x_test[0][0][1]])
    valores=np.array([x_test[0][0][2:9]])
    parcial=model.predict([dia, mes, valores])
    results.append(parcial[0])
    print('pred',i,x_test)
    x_test,ultDiaSemana=agregarNuevoValor(x_test,parcial[0],ultDiaSemana)
# Out:
# 1/1 [==============================] - 0s 163ms/step
# pred 0 [[[ 3.         12.          0.28571439  0.80952382  0.38095236
#     1.         -0.90476191 -0.28571415  0.0476191 ]]
#
#  [[ 4.         12.          0.80952382  0.38095236  1.
#    -0.90476191 -0.28571415  0.0476191  -1.        ]]
#
#  [[ 5.         12.          0.38095236  1.         -0.90476191
#    -0.28571415  0.0476191  -1.         -0.85714281]]]
# 1/1 [==============================] - 0s 57ms/step
# pred 1 [[[ 6.         12.          0.80952382  0.38095236  1.
#    -0.90476191 -0.28571415  0.0476191   0.01497963]]
#
#  [[ 4.         12.          0.80952382  0.38095236  1.
#    -0.90476191 -0.28571415  0.0476191  -1.        ]]
#
#  [[ 5.         12.          0.38095236  1.         -0.90476191
#    -0.28571415  0.0476191  -1.         -0.85714281]]]
# 1/1 [==============================] - 0s 21ms/step
# pred 2 [[[ 0.00000000e+00  1.20000000e+01  3.80952358e-01  1.00000000e+00
#    -9.04761910e-01 -2.85714149e-01  4.76191044e-02  1.49796344e-02
#     1.96070038e-03]]
#
#  [[ 4.00000000e+00  1.20000000e+01  8.09523821e-01  3.80952358e-01
#     1.00000000e+00 -9.04761910e-01 -2.85714149e-01  4.76191044e-02
#    -1.00000000e+00]]
#
#  [[ 5.00000000e+00  1.20000000e+01  3.80952358e-01  1.00000000e+00
#    -9.04761910e-01 -2.85714149e-01  4.76191044e-02 -1.00000000e+00
#    -8.57142806e-01]]]
# 1/1 [==============================] - 0s 28ms/step
# pred 3 [[[ 1.00000000e+00  1.20000000e+01  1.00000000e+00 -9.04761910e-01
#    -2.85714149e-01  4.76191044e-02  1.49796344e-02  1.96070038e-03
#    -2.81090979e-02]]
#
#  [[ 4.00000000e+00  1.20000000e+01  8.09523821e-01  3.80952358e-01
#     1.00000000e+00 -9.04761910e-01 -2.85714149e-01  4.76191044e-02
#    -1.00000000e+00]]
#
#  [[ 5.00000000e+00  1.20000000e+01  3.80952358e-01  1.00000000e+00
#    -9.04761910e-01 -2.85714149e-01  4.76191044e-02 -1.00000000e+00
#    -8.57142806e-01]]]
# 1/1 [==============================] - 0s 34ms/step
# pred 4 [[[ 2.00000000e+00  1.20000000e+01 -9.04761910e-01 -2.85714149e-01
#     4.76191044e-02  1.49796344e-02  1.96070038e-03 -2.81090979e-02
#     1.11429933e-02]]
#
#  [[ 4.00000000e+00  1.20000000e+01  8.09523821e-01  3.80952358e-01
#     1.00000000e+00 -9.04761910e-01 -2.85714149e-01  4.76191044e-02
#    -1.00000000e+00]]
#
#  [[ 5.00000000e+00  1.20000000e+01  3.80952358e-01  1.00000000e+00
#    -9.04761910e-01 -2.85714149e-01  4.76191044e-02 -1.00000000e+00
#    -8.57142806e-01]]]
# 1/1 [==============================] - 0s 22ms/step
# pred 5 [[[ 3.00000000e+00  1.20000000e+01 -2.85714149e-01  4.76191044e-02
#     1.49796344e-02  1.96070038e-03 -2.81090979e-02  1.11429933e-02
#    -1.36407129e-02]]
#
#  [[ 4.00000000e+00  1.20000000e+01  8.09523821e-01  3.80952358e-01
#     1.00000000e+00 -9.04761910e-01 -2.85714149e-01  4.76191044e-02
#    -1.00000000e+00]]
#
#  [[ 5.00000000e+00  1.20000000e+01  3.80952358e-01  1.00000000e+00
#    -9.04761910e-01 -2.85714149e-01  4.76191044e-02 -1.00000000e+00
#    -8.57142806e-01]]]
# 1/1 [==============================] - 0s 27ms/step
# pred 6 [[[ 4.00000000e+00  1.20000000e+01  4.76191044e-02  1.49796344e-02
#     1.96070038e-03 -2.81090979e-02  1.11429933e-02 -1.36407129e-02
#     1.49796344e-02]]
#
#  [[ 4.00000000e+00  1.20000000e+01  8.09523821e-01  3.80952358e-01
#     1.00000000e+00 -9.04761910e-01 -2.85714149e-01  4.76191044e-02
#    -1.00000000e+00]]
#
#  [[ 5.00000000e+00  1.20000000e+01  3.80952358e-01  1.00000000e+00
#    -9.04761910e-01 -2.85714149e-01  4.76191044e-02 -1.00000000e+00
#    -8.57142806e-01]]]

# %%
adimen = [x for x in results]    
print(adimen)
inverted = scaler.inverse_transform(adimen)
inverted
# Out:
# [array([0.01497963], dtype=float32), array([0.0019607], dtype=float32), array([-0.0281091], dtype=float32), array([0.01114299], dtype=float32), array([-0.01364071], dtype=float32), array([0.01497963], dtype=float32), array([-0.00082866], dtype=float32)]
# array([[55.31457177],
#        [55.04117416],
#        [54.40970841],
#        [55.23400231],
#        [54.71354449],
#        [55.31457177],
#        [54.98259769]])

# %%
prediccion1SemanaEnero = pd.DataFrame(inverted)
prediccion1SemanaEnero.columns = ['pronostico']
prediccion1SemanaEnero.plot()
prediccion1SemanaEnero.to_csv(r'/home/dsc/Master DS/TFM/GIT/DATOS_PROCESADOS/pronostico_embeddings.csv')
